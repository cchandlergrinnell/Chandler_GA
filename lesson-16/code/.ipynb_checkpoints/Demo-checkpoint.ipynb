# %%
import pandas as pd

# %%
data = pd.read_csv('../datasets/rossmann.csv')

data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)

data['Year'] = data.index.year
data['Month'] = data.index.month

data.head()
# Out:
# /Users/edwardlee/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2015-07-31      1          5   5263        555     1      1            0
# 2015-07-31      2          5   6064        625     1      1            0
# 2015-07-31      3          5   8314        821     1      1            0
# 2015-07-31      4          5  13995       1498     1      1            0
# 2015-07-31      5          5   4822        559     1      1            0
#
#             SchoolHoliday  Year  Month
# Date
# 2015-07-31              1  2015      7
# 2015-07-31              1  2015      7
# 2015-07-31              1  2015      7
# 2015-07-31              1  2015      7
# 2015-07-31              1  2015      7

# %%
data.index.year
# Out:
# array([2015, 2015, 2015, ..., 2013, 2013, 2013], dtype=int32)

# %%
data['2014'].head()
# Out:
#             Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2014-12-31      1          3   2605        327     1      0            0
# 2014-12-31      2          3   2269        252     1      0            0
# 2014-12-31      3          3   3804        408     1      0            0
# 2014-12-31      4          3  10152       1311     1      0            0
# 2014-12-31      5          3   1830        217     1      0            0
#
#             SchoolHoliday  Year  Month
# Date
# 2014-12-31              1  2014     12
# 2014-12-31              1  2014     12
# 2014-12-31              1  2014     12
# 2014-12-31              1  2014     12
# 2014-12-31              1  2014     12

# %%
data['2014-05'].head()
# Out:
#             Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2014-05-31      1          6   4985        560     1      0            0
# 2014-05-31      2          6   2953        485     1      0            0
# 2014-05-31      3          6   4725        514     1      0            0
# 2014-05-31      4          6  11018       1542     1      0            0
# 2014-05-31      5          6   2026        235     1      0            0
#
#             SchoolHoliday  Year  Month
# Date
# 2014-05-31              0  2014      5
# 2014-05-31              0  2014      5
# 2014-05-31              0  2014      5
# 2014-05-31              0  2014      5
# 2014-05-31              0  2014      5

# %%
import seaborn as sb
# %matplotlib inline

# %%
store1_data = data[data.Store == 1]
store1_data.index
# Out:
# DatetimeIndex(['2015-07-31', '2015-07-30', '2015-07-29', '2015-07-28',
#                '2015-07-27', '2015-07-26', '2015-07-25', '2015-07-24',
#                '2015-07-23', '2015-07-22',
#                ...
#                '2013-01-10', '2013-01-09', '2013-01-08', '2013-01-07',
#                '2013-01-06', '2013-01-05', '2013-01-04', '2013-01-03',
#                '2013-01-02', '2013-01-01'],
#               dtype='datetime64[ns]', name=u'Date', length=942, freq=None)

# %%
sb.factorplot(
    col='Open',
    x='SchoolHoliday',
    y='Sales',
    data=store1_data, 
    kind='box'
)

# %%
#TODO: Check if there is a difference affecting sales on promotion days.

# %%
sb.factorplot(
    col='Open',
    x='DayOfWeek',
    y='Sales',
    data=store1_data,
    kind='box',
    
)

# %%
store1_open_data = store1_data[store1_data.Open==1]
store1_open_data[['Sales']].plot()

# %%
store1_open_data[['Customers']].plot()

# %%
#TODO: Use the index filtering to filter to just 2015.  Zoom in on changes over time.

# %%
data['Sales'].resample('D', how='mean').autocorr(lag=1)
# Out:
# /Users/edwardlee/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).mean()
#   if __name__ == '__main__':
# -0.025858276006383588

# %%
data[['Sales']].resample('A', how=['median', 'mean'])
# Out:
# /Users/edwardlee/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
#   if __name__ == '__main__':
#             Sales
#            median         mean
# Date
# 2013-12-31   5598  5658.533675
# 2014-12-31   5794  5833.290704
# 2015-12-31   5916  5878.245380

# %%
data[['Sales']].resample('M', how=['median', 'mean']).plot()
# Out:
# /Users/edwardlee/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
#   if __name__ == '__main__':

# %%
pd.rolling_mean(store1_data[['Sales']], window=3, center=True, freq='D').plot()
# Out:
# /Users/edwardlee/anaconda/lib/python2.7/site-packages/pandas/core/generic.py:5504: FutureWarning: The freq kw is deprecated and will be removed in a future version. You can resample prior to passing to a window function
#   on=on, axis=axis)
# /Users/edwardlee/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(freq=D,window=3,center=True).mean()
#   if __name__ == '__main__':

# %%
pd.rolling_mean(store1_data[['Sales']], window=3, center=True, freq='D')['2015'].plot()
# Out:
# /Users/edwardlee/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(freq=D,window=3,center=True).mean()
#   if __name__ == '__main__':

# %%
pd.rolling_mean(store1_data[['Sales']], window=10, center=True, freq='D')['2015'].plot()
# Out:
# /Users/edwardlee/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(freq=D,window=10,center=True).mean()
#   if __name__ == '__main__':

# %%
pd.ewma(store1_data['Sales'], span=10)['2015'].plot()
# Out:
# /Users/edwardlee/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(ignore_na=False,span=10,min_periods=0,adjust=True).mean()
#   if __name__ == '__main__':

# %%
store1_data['Sales'].diff(periods=1)['2015'].plot()

# %%
store1_data['Sales'].diff(periods=7)['2015'].plot()

# %%
pd.expanding_mean(store1_data['Sales'], freq='d').plot()
# Out:
# /Users/edwardlee/anaconda/lib/python2.7/site-packages/pandas/core/window.py:1810: FutureWarning: The freq kw is deprecated and will be removed in a future version. You can resample prior to passing to a window function
#   return Expanding(obj, **kwds)
# /Users/edwardlee/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: pd.expanding_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.expanding(min_periods=1,freq=d).mean()
#   if __name__ == '__main__':

# %%
pd.expanding_sum(store1_data['Sales'], freq='d').plot()
# Out:
# /Users/edwardlee/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: pd.expanding_sum is deprecated for Series and will be removed in a future version, replace with
# 	Series.expanding(min_periods=1,freq=d).sum()
#   if __name__ == '__main__':
